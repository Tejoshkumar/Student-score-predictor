# %%
# Step 1: Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Step 2: Load the dataset from working URL
url = "https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv"
data = pd.read_csv(url)

# Step 3: View the data
print("📊 First 5 rows of the dataset:")
print(data.head())

# Step 4: Plot the data
plt.scatter(data['Hours'], data['Scores'])
plt.xlabel('Hours Studied')
plt.ylabel('Score (%)')
plt.title('Hours vs Scores')
plt.show()
# Step 5: Split data into input (X) and output (y)
X = data[['Hours']]  # input features (2D)
y = data['Scores']   # output labels

# Step 6: Train the Linear Regression model
model = LinearRegression()
model.fit(X, y)

# Step 7: Predict score for a new input
hours = 9.25
predicted_score = model.predict([[hours]])
print(f"\n📈 If a student studies for {hours} hours, the predicted score is {predicted_score[0]:.2f}")
# Out:
# 📊 First 5 rows of the dataset:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 📈 If a student studies for 9.25 hours, the predicted score is 92.91
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
